# %%
import pandas as pd
import matplotlib.pyplot as plt
import warnings
import sys, os
warnings
warnings.filterwarnings('ignore')

# %%
# Add the scripts directory to the system path
sys.path.append('../scripts')

# %%
# Import the DataPipeline class
from datapipeline import DataPipeline

# %%
# Define file paths
train_path = '../data/train.csv'
store_path = '../data/store.csv'
test_path = '../data/test.csv'

# Initialize the DataPipeline
pipeline = DataPipeline(train_path, store_path, test_path)

# %%
# Load the data
merged_data, test_data, store_data = pipeline.load_data()
# Out:
# 2024-09-20 16:39:24,655 - INFO - Loading data...
# 2024-09-20 16:39:26,216 - INFO - Data loaded successfully.

# %%
# Clean the store data
cleaned_store_data = pipeline.clean_store_data(store_data)
# Out:
# 2024-09-20 16:39:26,247 - INFO - Cleaning store data...
# 2024-09-20 16:39:26,250 - INFO - Store data cleaned successfully.

# %%
# Clean the train data
cleaned_train_data = pipeline.clean_train_data()
# Out:
# 2024-09-20 16:39:26,269 - INFO - Cleaning train data...
# 2024-09-20 16:39:27,000 - INFO - Train data cleaned successfully.

# %%
# Detect outliers in the merged data
pipeline.detect_outliers()
# Out:
# 2024-09-20 16:39:27,019 - INFO - Detecting outliers...
# 2024-09-20 16:39:27,463 - INFO - Outliers detected and removed.

# %%
# Visualize promo distribution
pipeline.plot_promo_distribution(merged_data, test_data)
# Out:
# 2024-09-20 16:39:28,985 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-09-20 16:39:29,817 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-09-20 16:39:30,795 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-09-20 16:39:30,835 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
# Visualize sales trend by month
sales_trained=pipeline.sales_trend_by_month()
sales_trained
# Out:
# 2024-09-20 16:39:31,049 - INFO - Visualizing sales trend by month...
# 2024-09-20 16:39:31,700 - INFO - Sales trend visualization completed.

# %%
# Visualize sales per store with and without promos
pipeline.sales_per_store_with_promos()
# Out:
# 2024-09-20 16:39:31,717 - INFO - Visualizing sales per store with and without promos...
# 2024-09-20 16:39:44,137 - INFO - Sales per store visualization completed.

# %%
# Visualize sales distribution by day
pipeline.sales_distribution_by_day()
# Out:
# 2024-09-20 16:39:44,154 - INFO - Visualizing sales distribution across days of the week...
# 2024-09-20 16:39:45,321 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-09-20 16:39:45,967 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2024-09-20 16:39:46,705 - INFO - Sales distribution visualization completed.

# %%
merged_data
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %%
# Visualize sales by assortment type
pipeline.sales_by_assortment()
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType_x', 'Assortment_x',
#        'CompetitionDistance_x', 'CompetitionOpenSinceMonth_x',
#        'CompetitionOpenSinceYear_x', 'Promo2_x', 'Promo2SinceWeek_x',
#        'Promo2SinceYear_x', 'PromoInterval_x', 'Month', 'StoreType_y',
#        'Assortment_y', 'CompetitionDistance_y', 'CompetitionOpenSinceMonth_y',
#        'CompetitionOpenSinceYear_y', 'Promo2_y', 'Promo2SinceWeek_y',
#        'Promo2SinceYear_y', 'PromoInterval_y'],
#       dtype='object')
#    Store  DayOfWeek       Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5 2015-07-31   5263        555     1      1            0
# 1      2          5 2015-07-31   6064        625     1      1            0
# 2      3          5 2015-07-31   8314        821     1      1            0
# 3      4          5 2015-07-31  13995       1498     1      1            0
# ...

# %%
# Visualize sales vs competitor distance
pipeline.sales_vs_competitor_distance()
# Out:
# 2024-09-20 16:39:55,939 - INFO - Sales vs competitor distance visualized.
